# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data=pd.read_csv("thermodynamics.csv")

# %%
data
# Out:
#      Step  Time   Volume  Temperature  ...  Kinetic  Potential   Energy   Density
# 0       1   0.5  9194.67      292.503  ...  807.017   -2647.57 -1840.56  1.005360
# 1       2   1.0  9302.99      293.461  ...  809.662   -2629.40 -1819.74  0.993652
# 2       3   1.5  9113.69      298.554  ...  823.711   -2628.33 -1804.62  1.014290
# 3       4   2.0  9198.38      302.528  ...  834.677   -2629.24 -1794.57  1.004950
# 4       5   2.5  9130.54      290.567  ...  801.676   -2591.64 -1789.97  1.012420
# ..    ...   ...      ...          ...  ...      ...        ...      ...       ...
# 194   195  97.5  9192.93      297.812  ...  821.665   -2642.75 -1821.08  1.005550
# 195   196  98.0  9337.59      296.965  ...  819.329   -2596.11 -1776.78  0.989970
# 196   197  98.5  9119.26      309.630  ...  854.271   -2628.38 -1774.11  1.013670
# 197   198  99.0  9022.08      295.689  ...  815.807   -2629.19 -1813.38  1.024590
# 198   199  99.5  8865.98      300.846  ...  830.037   -2690.37 -1860.33  1.042630
#
# [199 rows x 9 columns]

# %%
data.head()
# Out:
#    Step  Time   Volume  Temperature  ...  Kinetic  Potential   Energy   Density
# 0     1   0.5  9194.67      292.503  ...  807.017   -2647.57 -1840.56  1.005360
# 1     2   1.0  9302.99      293.461  ...  809.662   -2629.40 -1819.74  0.993652
# 2     3   1.5  9113.69      298.554  ...  823.711   -2628.33 -1804.62  1.014290
# 3     4   2.0  9198.38      302.528  ...  834.677   -2629.24 -1794.57  1.004950
# 4     5   2.5  9130.54      290.567  ...  801.676   -2591.64 -1789.97  1.012420
#
# [5 rows x 9 columns]

# %%
data.tail()
# Out:
#      Step  Time   Volume  Temperature  ...  Kinetic  Potential   Energy  Density
# 194   195  97.5  9192.93      297.812  ...  821.665   -2642.75 -1821.08  1.00555
# 195   196  98.0  9337.59      296.965  ...  819.329   -2596.11 -1776.78  0.98997
# 196   197  98.5  9119.26      309.630  ...  854.271   -2628.38 -1774.11  1.01367
# 197   198  99.0  9022.08      295.689  ...  815.807   -2629.19 -1813.38  1.02459
# 198   199  99.5  8865.98      300.846  ...  830.037   -2690.37 -1860.33  1.04263
#
# [5 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Step         199 non-null    int64
#  1   Time         199 non-null    float64
#  2   Volume       199 non-null    float64
#  3   Temperature  199 non-null    float64
#  4   Pressure     199 non-null    float64
#  5   Kinetic      199 non-null    float64
#  6   Potential    199 non-null    float64
#  7   Energy       199 non-null    float64
#  8   Density      199 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 14.1 KB

# %%
data.describe()
# Out:
#              Step        Time  ...       Energy     Density
# count  199.000000  199.000000  ...   199.000000  199.000000
# mean   100.000000   50.000000  ... -1824.018593    1.026478
# std     57.590508   28.795254  ...    32.394689    0.015152
# min      1.000000    0.500000  ... -1912.660000    0.978717
# 25%     50.500000   25.250000  ... -1846.340000    1.014575
# 50%    100.000000   50.000000  ... -1824.730000    1.026990
# 75%    149.500000   74.750000  ... -1800.455000    1.036270
# max    199.000000   99.500000  ... -1753.220000    1.062270
#
# [8 rows x 9 columns]

# %%
data.shape
# Out:
# (199, 9)

# %%
data.dtypes
# Out:
# Step             int64
# Time           float64
# Volume         float64
# Temperature    float64
# Pressure       float64
# Kinetic        float64
# Potential      float64
# Energy         float64
# Density        float64
# dtype: object

# %%
scaler=StandardScaler()

# %%
scaled_data=scaler.fit_transform(data)

# %%
scaled_data
# Out:
# array([[-1.72336879, -1.72336879,  1.40836636, ...,  0.03986086,
#         -0.51190878, -1.39729555],
#        [-1.70596103, -1.70596103,  2.22316798, ...,  0.70852286,
#          0.1324101 , -2.1719619 ],
#        [-1.68855326, -1.68855326,  0.7992209 , ...,  0.74789921,
#          0.60033044, -0.80643712],
#        ...,
#        [ 1.68855326,  1.68855326,  0.8411194 , ...,  0.7460592 ,
#          1.54452683, -0.84745977],
#        [ 1.70596103,  1.70596103,  0.11011476, ...,  0.71625093,
#          0.32923373, -0.12493188],
#        [ 1.72336879,  1.72336879, -1.06409622, ..., -1.53519327,
#         -1.12373319,  1.06869478]])

# %%
pca=PCA(n_components=2)

# %%
pca_data=pca.fit_transform(scaled_data)

# %%
pca_scaled
# Out:
# array([[ 1.28204727, -2.43971528],
#        [ 2.74830524, -2.94897047],
#        [ 2.36499214, -1.31681662],
#        [ 3.30635143, -1.14589739],
#        [ 2.57262207, -2.38181511],
#        [ 2.16382883, -0.61559385],
#        [ 1.45393478,  1.60388396],
#        [ 1.04831959, -1.79610712],
#        [ 1.15992184, -3.04137059],
#        [ 1.38254768, -0.20021409],
#        [ 0.93906634, -1.38727383],
#        [ 1.60536939,  1.1480781 ],
#        [ 0.81373485,  0.98284953],
#        [ 0.68509236, -3.4208098 ],
#        [ 0.08147023,  0.06254784],
#        [ 0.54464611,  0.42637821],
#        [ 3.26798409, -1.66306654],
#        [ 2.96964325,  1.4073588 ],
#        [ 2.46006385, -1.83733724],
#        [ 1.18187749, -2.36115776],
#        [ 0.11080654, -0.60726138],
#        [ 0.51249125,  0.19001161],
#        [ 1.94070643,  1.09559476],
#        [ 2.26992397, -1.12545762],
#        [ 1.03004207, -1.08015358],
#        [ 1.16525003, -0.20859132],
#        [-0.05612426, -1.51936557],
#        [ 1.13804715, -2.84527938],
#        [ 0.73523845, -2.06039831],
#        [ 3.02410162, -3.44635792],
#        [ 3.96474168,  0.08250213],
#        [ 2.45222877,  1.48845604],
#        [ 2.29618317, -0.12044249],
#        [-0.96770748,  1.09408982],
#        [-1.87314848, -2.54491483],
#        [-1.45266382, -2.52254268],
#        [-0.0323993 ,  1.98366948],
#        [ 1.45284445,  0.72829696],
#        [ 2.86926953, -0.29222373],
#        [ 0.48313016,  0.65985351],
#        [-0.47700019,  0.08487098],
#        [-1.27352827,  0.09575374],
#        [-2.17321575, -0.20403718],
#        [ 0.48405262, -1.44843002],
#        [ 0.47411977,  0.60892659],
#        [ 0.91243068,  2.64207386],
#        [ 1.61432988,  0.63623299],
#        [ 0.02848817, -0.07454145],
#        [-1.31734566, -0.66294844],
#        [-0.88587322, -2.17336279],
#        [-0.26624217,  1.04707193],
#        [ 0.72155307,  2.46287029],
#        [ 3.01285302,  0.36584501],
#        [ 1.70892026,  0.34949557],
#        [ 1.79806509, -0.70358482],
#        [ 1.63021754, -0.43121673],
#        [-1.374599  ,  0.46193425],
#        [-1.1258147 , -2.30324468],
#        [ 0.63951632, -0.24383129],
#        [ 1.8727505 , -1.60250874],
#        [ 1.75342895, -2.27895352],
#        [ 1.2282395 ,  0.27686785],
#        [ 0.75850228,  2.35672973],
#        [-0.80326566, -0.25258777],
#        [-1.72933831, -0.07478822],
#        [-1.36967224, -2.48855404],
#        [-1.353502  , -1.454745  ],
#        [-0.6192983 , -0.18859674],
#        [ 0.82600548,  0.17085278],
#        [ 0.93486822,  1.48200662],
#        [-0.01231659,  1.03414373],
#        [-1.02424604, -2.81061392],
#        [-3.09320777,  0.07821233],
#        [-2.25661014, -0.59549278],
#        [-1.02227616, -2.43609904],
#        [ 0.78411332,  0.29134569],
#        [ 0.83639175,  4.7582929 ],
#        [ 0.49665583,  0.4945822 ],
#        [-0.80236585, -0.45729327],
#        [-2.9349456 , -2.10220442],
#        [-1.52972542, -2.04305802],
#        [-0.13178639,  1.67019468],
#        [ 2.72987493,  0.1132761 ],
#        [ 2.75440276,  0.9818069 ],
#        [ 1.40927733,  2.16970469],
#        [-1.24466845,  1.23703583],
#        [-1.15092555,  0.21123786],
#        [-1.10243155, -0.06781377],
#        [-0.38578622, -0.56983823],
#        [ 0.17301589,  2.18921702],
#        [ 1.53732299,  1.23302125],
#        [ 1.98781265, -1.34081061],
#        [ 0.45606184, -0.49110836],
#        [-1.38399622,  0.86972002],
#        [-1.74917559, -0.28217198],
#        [-1.61701768, -0.58489182],
#        [-1.6389381 ,  2.36759075],
#        [-0.76514635, -0.118156  ],
#        [ 1.89514568,  0.33574471],
#        [ 1.79310208, -0.63427101],
#        [ 0.98470866,  0.73563239],
#        [-0.19066047, -0.14574045],
#        [ 0.53472524, -2.33661348],
#        [ 1.20872217, -1.14859792],
#        [ 1.93217355, -1.95955907],
#        [-0.11060645, -1.74424122],
#        [-1.11215991, -1.4521591 ],
#        [-2.02229873,  1.63179072],
#        [-0.96527838,  1.0676856 ],
#        [-0.96090483,  1.59227132],
#        [ 0.72355185, -1.05671914],
#        [-0.54881075, -0.85601107],
#        [-0.56760269,  0.11063132],
#        [ 0.71453463, -0.46452168],
#        [-0.24521486,  1.05399712],
#        [ 0.65946419,  1.2775205 ],
#        [-0.73902913,  0.17436371],
#        [-0.72619779, -0.08995943],
#        [-0.65444884, -0.67199854],
#        [-0.16611102, -1.78503344],
#        [ 0.14877226, -1.30592724],
#        [ 0.01681713,  0.93116575],
#        [ 1.55797749, -0.5535499 ],
#        [ 0.70065153,  1.93727098],
#        [-0.78255245,  0.26075028],
#        [-0.08749034,  0.15803784],
#        [-0.50430555, -2.73426094],
#        [-0.84188229, -0.12054323],
#        [-2.16582128,  0.35160953],
#        [ 0.93636804, -1.37559243],
#        [-0.09723453,  2.6152336 ],
#        [-1.5596597 ,  1.57516011],
#        [-1.58038391,  0.82471419],
#        [-2.07214613, -0.95806736],
#        [-3.99190253,  0.29977313],
#        [-1.48045905, -0.23262801],
#        [-1.13620234,  3.79562159],
#        [ 1.63330794,  1.40140596],
#        [-0.14786056,  2.19567875],
#        [-1.45669197, -0.63954422],
#        [-2.45913241,  0.16173036],
#        [-2.04851387,  0.69246724],
#        [-0.50281579,  0.83955629],
#        [ 0.95031715,  0.99972174],
#        [ 1.0580614 ,  1.06120493],
#        [-0.05577729, -1.08721408],
#        [-1.19745278,  0.31527963],
#        [-1.55539001,  1.3870994 ],
#        [-0.13039261, -1.6170622 ],
#        [-0.40742336,  0.45913364],
#        [ 0.57751017,  1.6538342 ],
#        [ 1.04350265,  1.34634859],
#        [ 0.9550168 , -0.20140336],
#        [-1.20113   ,  1.79293906],
#        [-0.31650901, -1.82298181],
#        [-0.68900988,  0.88333528],
#        [-0.46280241,  1.8189143 ],
#        [ 1.7002917 , -0.53406796],
#        [ 1.38025554,  1.2148972 ],
#        [ 1.45277399, -0.83741996],
#        [ 1.35896317,  3.30367182],
#        [ 2.09397186,  1.39967474],
#        [-0.54537109, -1.78494586],
#        [-1.92531966,  0.59719346],
#        [-2.35495334, -0.20052083],
#        [-0.86335329,  1.11272313],
#        [-1.16813594,  1.40949291],
#        [-0.18724182,  2.69880837],
#        [-0.73485873,  1.32859133],
#        [-2.88491284,  1.29277847],
#        [-2.18181998, -1.67573555],
#        [-2.26209282,  0.04135624],
#        [-0.74935927, -1.33017783],
#        [ 1.41428673,  1.75494884],
#        [ 0.58363777,  4.80916523],
#        [ 0.81481271,  1.51137569],
#        [-1.26816846, -1.21230363],
#        [-4.39784916, -3.18915222],
#        [-4.03685208,  0.69852342],
#        [-3.25622525, -1.06620011],
#        [ 0.4312663 ,  3.03871729],
#        [ 0.66284063,  0.88899023],
#        [-0.94721802,  1.76069861],
#        [-1.6474969 , -1.48551765],
#        [-2.35733299,  0.23034426],
#        [-1.92411874, -1.25454282],
#        [-1.85505358, -0.18773258],
#        [-0.75796802,  3.37591838],
#        [ 0.83477871,  1.1461814 ],
#        [ 0.27273163,  1.05302479],
#        [-1.72549131,  1.54718102],
#        [-1.33893212, -3.95536462],
#        [-2.37274436, -0.67761688],
#        [-1.79535259,  0.15613259],
#        [ 0.13247616, -0.40443504],
#        [ 2.46329879, -1.23071566],
#        [ 1.51472012,  1.87126572],
#        [-0.68894745,  0.15901602],
#        [-3.01189097,  1.60248789]])

# %%
pca_df=pd.DataFrame(pca_data, columns=['PCA1', 'PCA2'])

# %%
pca_df
# Out:
#          PCA1      PCA2
# 0    1.282047 -2.439715
# 1    2.748305 -2.948970
# 2    2.364992 -1.316817
# 3    3.306351 -1.145897
# 4    2.572622 -2.381815
# ..        ...       ...
# 194  0.132476 -0.404435
# 195  2.463299 -1.230716
# 196  1.514720  1.871266
# 197 -0.688947  0.159016
# 198 -3.011891  1.602488
#
# [199 rows x 2 columns]

# %%
plt.figure(figsize=(16, 12))
plt.scatter(pca_df.PCA1, pca_df.PCA2)
plt.xlabel('Principal Component 1', fontsize=24)
plt.ylabel('Principal Component 2', fontsize=24)
plt.title('Principal Component Analysis of the Thermodynamics data', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(True)
plt.show()

# %%
plt.subplot(1, 2, 1)
scatter = plt.scatter(pca_df['PCA1'], pca_df['PCA2'], c=pca_df['PCA1'], cmap='coolwarm', marker='o', edgecolor='k')
plt.title('PCA Scatter Plot Colored by PCA1')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.colorbar(scatter, label='PCA1 Value')
plt.grid(True)

# %%
plt.subplot(1, 2, 1)
scatter = plt.scatter(pca_df['PCA1'], pca_df['PCA2'], c=pca_df['PCA2'], cmap='coolwarm', marker='o', edgecolor='k')
plt.title('PCA Scatter Plot Colored by PCA2')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.colorbar(scatter, label='PCA1 Value')
plt.grid(True)
